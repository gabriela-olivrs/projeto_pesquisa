# %% [markdown]
# ###### Bibliotecas

# %%
import pandas as pd

# %% [markdown]
# ###### Leitura

# %%
data_raw = pd.read_csv("~/Documentos/tcc/Desenvolvimento_TCC2/data/data_raw/formulario.csv")
data_raw
# Out:
#              Carimbo de data/hora  Sexo:             Estado Civil: Idade  \
# 0     2023/10/16 9:21:08 AM GMT-3   Homem  Casado(a)/União Estável    32
# 1     2023/10/16 9:22:10 AM GMT-3  Mulher  Casado(a)/União Estável    28
# 2     2023/10/16 9:22:28 AM GMT-3  Mulher  Casado(a)/União Estável    40
# 3     2023/10/16 9:23:20 AM GMT-3   Homem              Solteiro(a)    24
# 4     2023/10/16 9:24:58 AM GMT-3   Homem              Solteiro(a)    23
# ..                            ...     ...                      ...   ...
# 167   2023/10/23 8:42:36 PM GMT-3  Mulher  Casado(a)/União Estável    28
# 168   2023/10/23 9:22:18 PM GMT-3   Homem              Solteiro(a)    23
# 169  2023/10/23 11:42:30 PM GMT-3  Mulher              Solteiro(a)    22
# 170   2023/10/25 9:38:08 AM GMT-3  Mulher              Solteiro(a)    31
# 171   2023/10/25 4:13:09 PM GMT-3   Homem              Solteiro(a)    26
#
#     Telefone para contato (se deseja participar do sorteio) Possui Filhos:  \
# 0                                                  NaN                 Não
# 1                                                  NaN                 Não
# 2                                          31987122169                 Sim
# 3                                                  NaN                 Não
# 4                                          31995871329                 Não
# ..                                                 ...                 ...
# 167                                                NaN                 Não
# 168                                        82987311995                 Não
# 169                                        24999889760                 Não
# 170                                        11958102447                 Não
# 171                                        11948494955                 Não
#
#      Qual a idade média de seus filhos. Se você tiver apenas 1, indique sua idade diretamente.  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  3.0
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 167                                                NaN
# 168                                                NaN
# 169                                                NaN
# 170                                                NaN
# 171                                                NaN
#
#                    Cargo Atual / Senioridade:  \
# 0                                Dev - Senior
# 1                  Analista Data Analytics Jr
# 2                                   QA Senior
# 3                         Desenvolvedor pleno
# 4                        Programador Junior 1
# ..                                        ...
# 167               Analista de sistemas sênior
# 168  Engenheiro de software front-end / pleno
# 169               Analista de Suporte Júnior
# 170                        Data Developer Jr.
# 171              Desenvolvedor Frontend Pleno
#
#     Você trabalha (ou já trabalhou) no modelo remoto ou híbrido?  \
# 0                                                  Sim
# 1                                                  Sim
# 2                                                  Sim
# 3                                                  Sim
# 4                                                  Sim
# ..                                                 ...
# 167                                                Sim
# 168                                                Sim
# 169                                                Sim
# 170                                                Sim
# 171                                                Sim
#
#     Atualmente, você trabalha em qual modelo?  ...  \
# 0                                      Remoto  ...
# 1                                     Híbrido  ...
# 2                                      Remoto  ...
# 3                                      Remoto  ...
# 4                                      Remoto  ...
# ..                                        ...  ...
# 167                                    Remoto  ...
# 168                                    Remoto  ...
# 169                                    Remoto  ...
# 170                                   Híbrido  ...
# 171                                    Remoto  ...
#
#      Nível de Frustração:\n\nEm uma escala de 0 (satisfeito) a 5 (frustrado), indique o quão você se sente em relação ao seu modelo de trabalho atual, considerando os seguintes aspectos: [Vida pessoal]  \
# 0                                                  2.0
# 1                                                  5.0
# 2                                                  2.0
# 3                                                  0.0
# 4                                                  0.0
# ..                                                 ...
# 167                                                0.0
# 168                                                0.0
# 169                                                0.0
# 170                                                1.0
# 171                                                1.0
#
#     Nível de Frustração:\n\nEm uma escala de 0 (satisfeito) a 5 (frustrado), indique o quão você se sente em relação ao seu modelo de trabalho atual, considerando os seguintes aspectos: [Cuidados com os filhos]  \
# 0                                                  2.0
# 1                                                  0.0
# 2                                                  3.0
# 3                                                  0.0
# 4                                                  0.0
# ..                                                 ...
# 167                                                0.0
# 168                                                0.0
# 169                                                0.0
# 170                                                5.0
# 171                                                0.0
#
#     Nível de Frustração:\n\nEm uma escala de 0 (satisfeito) a 5 (frustrado), indique o quão você se sente em relação ao seu modelo de trabalho atual, considerando os seguintes aspectos: [Tarefas domésticas]  \
# 0                                                  2.0
# 1                                                  5.0
# 2                                                  3.0
# 3                                                  1.0
# 4                                                  0.0
# ..                                                 ...
# 167                                                1.0
# 168                                                0.0
# 169                                                1.0
# 170                                                3.0
# 171                                                0.0
#
#     Nível de Frustração:\n\nEm uma escala de 0 (satisfeito) a 5 (frustrado), indique o quão você se sente em relação ao seu modelo de trabalho atual, considerando os seguintes aspectos: [Estudos]  \
# 0                                                  2.0
# 1                                                  5.0
# 2                                                  2.0
# 3                                                  0.0
# 4                                                  0.0
# ..                                                 ...
# 167                                                0.0
# 168                                                0.0
# 169                                                0.0
# 170                                                3.0
# 171                                                0.0
#
#      Nível de Frustração:\n\nEm uma escala de 0 (satisfeito) a 5 (frustrado), indique o quão você se sente em relação ao seu modelo de trabalho atual, considerando os seguintes aspectos: [Desenvolvimento de carreira pessoal]  \
# 0                                                  2.0
# 1                                                  5.0
# 2                                                  2.0
# 3                                                  1.0
# 4                                                  0.0
# ..                                                 ...
# 167                                                0.0
# 168                                                0.0
# 169                                                0.0
# 170                                                1.0
# 171                                                1.0
#
#      Nível de Insegurança:\n\nEm uma escala de 0 (satisfeito) a 5 (inseguro), indique o quão você se sente em relação ao seu modelo de trabalho atual, considerando os seguintes aspectos: [Vida pessoal]  \
# 0                                                  2.0
# 1                                                  5.0
# 2                                                  2.0
# 3                                                  2.0
# 4                                                  0.0
# ..                                                 ...
# 167                                                0.0
# 168                                                0.0
# 169                                                0.0
# 170                                                3.0
# 171                                                0.0
#
#      Nível de Insegurança:\n\nEm uma escala de 0 (satisfeito) a 5 (inseguro), indique o quão você se sente em relação ao seu modelo de trabalho atual, considerando os seguintes aspectos: [Cuidados com os filhos]  \
# 0                                                  2.0
# 1                                                  0.0
# 2                                                  2.0
# 3                                                  0.0
# 4                                                  0.0
# ..                                                 ...
# 167                                                0.0
# 168                                                0.0
# 169                                                0.0
# 170                                                5.0
# 171                                                0.0
#
#      Nível de Insegurança:\n\nEm uma escala de 0 (satisfeito) a 5 (inseguro), indique o quão você se sente em relação ao seu modelo de trabalho atual, considerando os seguintes aspectos: [Tarefas domésticas]  \
# 0                                                  2.0
# 1                                                  5.0
# 2                                                  2.0
# 3                                                  2.0
# 4                                                  0.0
# ..                                                 ...
# 167                                                0.0
# 168                                                0.0
# 169                                                0.0
# 170                                                1.0
# 171                                                0.0
#
#      Nível de Insegurança:\n\nEm uma escala de 0 (satisfeito) a 5 (inseguro), indique o quão você se sente em relação ao seu modelo de trabalho atual, considerando os seguintes aspectos: [Estudos]  \
# 0                                                  2.0
# 1                                                  5.0
# 2                                                  3.0
# 3                                                  2.0
# 4                                                  1.0
# ..                                                 ...
# 167                                                0.0
# 168                                                0.0
# 169                                                1.0
# 170                                                3.0
# 171                                                1.0
#
#      Nível de Insegurança:\n\nEm uma escala de 0 (satisfeito) a 5 (inseguro), indique o quão você se sente em relação ao seu modelo de trabalho atual, considerando os seguintes aspectos: [Desenvolvimento de carreira pessoal]
# 0                                                  2.0
# 1                                                  5.0
# 2                                                  3.0
# 3                                                  2.0
# 4                                                  0.0
# ..                                                 ...
# 167                                                0.0
# 168                                                0.0
# 169                                                0.0
# 170                                                1.0
# 171                                                1.0
#
# [172 rows x 34 columns]

# %%
data_refined = data_raw

# %%
# Filtrar o DataFrame para remover profissões que não estão envolvidas com TI
profissoes_a_remover = ['Técnico de controle ferroviário', 'Engenheiro Mecânico', 'Consultor de negócios jr com python']
data_refined= data_refined[~data_refined['Cargo Atual / Senioridade:'].isin(profissoes_a_remover)]

# %%
#Removendo pessoas que nunca trabalhavam homeoffice ou hibrido
data_refined = data_refined.loc[~(data_refined['Você trabalha (ou já trabalhou) no modelo remoto ou híbrido?'].str.contains('não', case=False, na=False))]

# %%
#Removendo colunas desnecessárias para analise e renomeando as necessárias
colunas_para_remover = ['Carimbo de data/hora', 'Telefone para contato (se deseja participar do sorteio)', 'Você trabalha (ou já trabalhou) no modelo remoto ou híbrido?']

novos_nomes = ['sexo',
'estado_civil',
'idade',
'possui_filhos', 
'idade_media_filhos', 
'cargo_atual/senioridade', 
'home_office/hibrido',
'avaliação_ambiente_trabalho', 
'modelo_ideal', 
'modelo_pre_pandemia',
'modelo_pos_pandemia', 
'satisfacao_vida_pessoal',
'satisfacao_cuidado_filhos',
'satisfacao_tarefas_domesticas',
'satisfacao_estudos', 
'satisfacao_dev_carreira',
'sobrecarga_vida_pessoal',
'sobrecarga_cuidado_filhos',
'sobrecarga_tarefas_domesticas',
'sobrecarga_estudos', 
'sobrecarga_dev_carreira',
'frustracao_vida_pessoal',
'frustracao_cuidado_filhos',
'frustracao_tarefas_domesticas',
'frustracao_estudos', 
'frustracao_dev_carreira',
'inseguranca_vida_pessoal',
'inseguranca_cuidado_filhos',
'inseguranca_tarefas_domesticas',
'inseguranca_estudos', 
'inseguranca_dev_carreira']


# Use o método set_axis para renomear as colunas
data_refined = data_refined.drop(colunas_para_remover, axis=1)
data_refined = data_refined.set_axis(novos_nomes, axis=1, copy=False)

# %%
# Substituindo 'idade_media_filhos' por 'Não se aplica' quando 'possui_filhos' for igual a 'nao'
data_refined.loc[data_refined['possui_filhos'] == 'Não', 'idade_media_filhos'] = 'Não se aplica'

# Substituindo o nivel de sentimentos por 'Não se aplica' quando 'possui_filhos' for igual a 'nao'
data_refined.loc[data_refined['possui_filhos'] == 'Não', 'satisfacao_cuidado_filhos'] = 'Não se aplica'
data_refined.loc[data_refined['possui_filhos'] == 'Não', 'sobrecarga_cuidado_filhos'] = 'Não se aplica'
data_refined.loc[data_refined['possui_filhos'] == 'Não', 'frustracao_cuidado_filhos'] = 'Não se aplica'
data_refined.loc[data_refined['possui_filhos'] == 'Não', 'inseguranca_cuidado_filhos'] = 'Não se aplica'

# %%
# Criando dicionários de mapeamento de substituição

#Estado Civil
substituicoes_est_civil = {'Divorciada(a)': 'Divorciado(o)', 'Divorciado': 'Divorciado(o)', 'Namorando (morando junto)' : 'Casado(a)/União Estável', 'Morando junto':'Casado(a)/União Estável', 'Namorido? Mas oficialmente, solteira': 'Solteiro(a)'}
data_refined['estado_civil'] = data_refined['estado_civil'].replace(substituicoes_est_civil)

#Idade
substituicoes_idade = {' anos': ''}
data_refined['idade'] = data_refined['idade'].replace(substituicoes_idade)

# %%
#Padronização de Cargos

traducao_cargo = {'Data developer':'Desenvolvedor de Dados',
                  'Data Developer':'Desenvolvedor de Dados',
                  'Data Developer Jr.':'Desenvolvedor de Dados',
                  'Senior Software Developer':'Desenvolvedor Software Senior',
                  'Unity Developer / Pleno':'Desenvolvedor Unity',
                  'Junior System Analist':'Analista de Sistemas Júnior',
                  'Analista Data Analytics Jr':'Analista de Dados Jr',
                  'Data Engenieer':'Engenheiro de Dados'}

data_refined['cargo_atual/senioridade'] = data_refined['cargo_atual/senioridade'].replace(traducao_cargo)

# %%
padronizacao_cargo = {' jr':'Júnior','jr':'Júnior','JR':'Júnior','/jr':'Júnior','Jr':'Júnior','Junior':'Júnior','junior':'Júnior',
                       'Dev':'Desenvolvedor(a)','developer':'Desenvolvedor(a)','desenvolvedor':'Desenvolvedor(a)',
                       'desenvolvedora':'Desenvolvedor(a)','Desenvolvedora':'Desenvolvedor(a)','Desenvolver':'Desenvolvedor(a)', 
                       'Desenvolvedor':'Desenvolvedor(a)','Programador':'Desenvolvedor(a)',
                       'Profressora':'Professor(a)','Professor':'Professor(a)',
                       ' pl ':'Pleno',' Pl ':'Pleno',' PL ':'Pleno','Plena':'Pleno','plena':'Pleno','pleno':'Pleno',
                       'Senior':'Sênior','sênior': 'Sênior','senior':'Sênior',
                       'engenheiro':'Engenheiro(a)','Engenheira':'engenheira(a)','Engenheiro':'Engenheiro(a)','Engenheira':'Engenheiro(a)',
                       'analista':'Analista','Arquiteto':'Arquiteto(a)','Gestor':'Gestor(a)','Intern':'Estagiário(a)','Estagio':'Estagiário(a)',
                       'Estagiário':'Estagiário(a)','Estagiária':'Estagiário(a)','estagiária':'Estagiário(a)','Estágio':'Estagiário(a)','Estágiario':'Estagiário(a)',
                       'dados':'Dados','fullstack':'Full Stack','Fullstack':'Full Stack','master':'Master','sistemas':'Sistemas',
                       'tecnico':'Técnico(a)','Tecnico':'Técnico(a)','leader':'Leader','Lead':'Leader','Líder': 'Leader',
                       'Front End':'Frontend','front end':'Frontend', 'Diretor':'Diretor(a)'}

data_refined['cargo_atual/senioridade'] = data_refined['cargo_atual/senioridade'].replace(padronizacao_cargo, regex=True)

# %%
remocao_sinais = {'/':' ',
                  ' / ':' ', 
                  '/ ':' ',
                  ' /':' ',
                  ' - ':' ',
                  ' I ' : '',
                  ' II ':'',
                  ' III ':'',
                  ' 1':'',
                  ' 2':'',
                  ' 3':'',
                  ' 4':''}

data_refined['cargo_atual/senioridade'] = data_refined['cargo_atual/senioridade'].replace(remocao_sinais, regex=True)

# %%
data_refined.to_csv('~/Documentos/tcc/Desenvolvimento_TCC2/data/data_refined/formulario_refined.csv', index=False)

# %%
data_refined
# Out:
#        sexo             estado_civil idade possui_filhos idade_media_filhos  \
# 0     Homem  Casado(a)/União Estável    32           Não      Não se aplica
# 1    Mulher  Casado(a)/União Estável    28           Não      Não se aplica
# 2    Mulher  Casado(a)/União Estável    40           Sim                3.0
# 3     Homem              Solteiro(a)    24           Não      Não se aplica
# 4     Homem              Solteiro(a)    23           Não      Não se aplica
# ..      ...                      ...   ...           ...                ...
# 167  Mulher  Casado(a)/União Estável    28           Não      Não se aplica
# 168   Homem              Solteiro(a)    23           Não      Não se aplica
# 169  Mulher              Solteiro(a)    22           Não      Não se aplica
# 170  Mulher              Solteiro(a)    31           Não      Não se aplica
# 171   Homem              Solteiro(a)    26           Não      Não se aplica
#
#                          cargo_atual/senioridade home_office/hibrido  \
# 0                        Desenvolvedor(a) Sênior              Remoto
# 1                       Analista de Dados Júnior             Híbrido
# 2                                      QA Sênior              Remoto
# 3                         Desenvolvedor(a) Pleno              Remoto
# 4                        Desenvolvedor(a) Júnior              Remoto
# ..                                           ...                 ...
# 167                  Analista de Sistemas Sênior              Remoto
# 168  Engenheiro(a) de software front-end   Pleno              Remoto
# 169                  Analista de Suporte Júnior               Remoto
# 170                    Desenvolvedor(a) de Dados             Híbrido
# 171              Desenvolvedor(a) Frontend Pleno              Remoto
#
#      avaliação_ambiente_trabalho modelo_ideal modelo_pre_pandemia  ...  \
# 0                            5.0       Remoto                 Não  ...
# 1                            5.0      Híbrido                 Não  ...
# 2                            4.0       Remoto                 Não  ...
# 3                            5.0       Remoto                 Não  ...
# 4                            5.0       Remoto                 Não  ...
# ..                           ...          ...                 ...  ...
# 167                          4.0       Remoto                 Não  ...
# 168                          4.0       Remoto                 Não  ...
# 169                          5.0       Remoto                 Não  ...
# 170                          2.0      Híbrido                 Não  ...
# 171                          5.0       Remoto                 Não  ...
#
#     frustracao_vida_pessoal  frustracao_cuidado_filhos  \
# 0                       2.0              Não se aplica
# 1                       5.0              Não se aplica
# 2                       2.0                        3.0
# 3                       0.0              Não se aplica
# 4                       0.0              Não se aplica
# ..                      ...                        ...
# 167                     0.0              Não se aplica
# 168                     0.0              Não se aplica
# 169                     0.0              Não se aplica
# 170                     1.0              Não se aplica
# 171                     1.0              Não se aplica
#
#     frustracao_tarefas_domesticas  frustracao_estudos  \
# 0                             2.0                 2.0
# 1                             5.0                 5.0
# 2                             3.0                 2.0
# 3                             1.0                 0.0
# 4                             0.0                 0.0
# ..                            ...                 ...
# 167                           1.0                 0.0
# 168                           0.0                 0.0
# 169                           1.0                 0.0
# 170                           3.0                 3.0
# 171                           0.0                 0.0
#
#      frustracao_dev_carreira  inseguranca_vida_pessoal  \
# 0                        2.0                       2.0
# 1                        5.0                       5.0
# 2                        2.0                       2.0
# 3                        1.0                       2.0
# 4                        0.0                       0.0
# ..                       ...                       ...
# 167                      0.0                       0.0
# 168                      0.0                       0.0
# 169                      0.0                       0.0
# 170                      1.0                       3.0
# 171                      1.0                       0.0
#
#      inseguranca_cuidado_filhos inseguranca_tarefas_domesticas  \
# 0                 Não se aplica                            2.0
# 1                 Não se aplica                            5.0
# 2                           2.0                            2.0
# 3                 Não se aplica                            2.0
# 4                 Não se aplica                            0.0
# ..                          ...                            ...
# 167               Não se aplica                            0.0
# 168               Não se aplica                            0.0
# 169               Não se aplica                            0.0
# 170               Não se aplica                            1.0
# 171               Não se aplica                            0.0
#
#      inseguranca_estudos  inseguranca_dev_carreira
# 0                    2.0                       2.0
# 1                    5.0                       5.0
# 2                    3.0                       3.0
# 3                    2.0                       2.0
# 4                    1.0                       0.0
# ..                   ...                       ...
# 167                  0.0                       0.0
# 168                  0.0                       0.0
# 169                  1.0                       0.0
# 170                  3.0                       1.0
# 171                  1.0                       1.0
#
# [167 rows x 31 columns]

# %%
# Defina a função para mapear os cargos para os níveis
def classificar_nivel(cargo):
    if 'Sênior' in cargo or 
       'Gerente' in cargo or 
       'Diretor' in cargo  or 
       'Leader' in cargo or 
       'Professor(a)' in cargo:
        return 'Avançado'
    
    elif 'Júnior' in cargo or
         'Estagiário(a)' in cargo or
         'Auxiliar' in cargo:
        return 'Entrada'
    
    elif 'pleno' in cargo:
        return 'Intermediário'
    else:
        return 'Outro'

# Aplique a função à coluna "Cargo" para criar a nova coluna "Nível"
df['Nível'] = df['Cargo'].apply(classificar_nivel)

# Exiba o DataFrame resultante
print(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_265687/217380867.py in <module>
#      11
#      12 # Aplique a função à coluna "Cargo" para criar a nova coluna "Nível"
# ---> 13 df['Nível'] = df['Cargo'].apply(classificar_nivel)
#      14
#      15 # Exiba o DataFrame resultante
#
# NameError: name 'df' is not defined
